# %%
from agent_manager import AgentManager
from glob import glob

datasets = sorted(glob('agent_workspace/datasets/*'))
data_path = glob(datasets[2] + '/*') # assuming the data is uploaded via web interface / API

user_prompt = "Build a text regression model to prediction 'OverallRating' for airline reviews dataset."
manager = AgentManager(llm='gpt-4', interactive=False, data_path=data_path, n_revise=3)

manager.initiate_chat(user_prompt)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from agent_manager import AgentManager
#       2 from glob import glob
#       4 datasets = sorted(glob('agent_workspace/datasets/*'))
#
# File e:\Code\AutoML\automl-agent\automl-agent\agent_manager\__init__.py:7
#       5 from configs import AVAILABLE_LLMs
#       6 from prompt_agent import PromptAgent
# ----> 7 from data_agent import DataAgent
#       8 from model_agent import ModelAgent
#       9 from operation_agent import OperationAgent
#
# File e:\Code\AutoML\automl-agent\automl-agent\data_agent\__init__.py:2
#       1 from configs import AVAILABLE_LLMs
# ----> 2 from data_agent import retriever
#       3 from utils import print_message, get_client
#       6 # agent_profile = """You are a helpful assistant."""
#       7
#       8 # agent_profile = """You are a helpful assistant. You have the following main responsibilities to complete.
#    (...)
#      23 # 3. Perform data augmentation as neccesary.
#      24 # 4. Extract useful information and underlying characteristics of the dataset."""
#
# File e:\Code\AutoML\automl-agent\automl-agent\data_agent\retriever.py:6
#       4 from openai import OpenAI
#       5 from utils import get_kaggle, search_web, print_message
# ----> 6 from utils.embeddings import chunk_and_retrieve
#       7 from configs import AVAILABLE_LLMs
#       8 from validators import url
#
# File e:\Code\AutoML\automl-agent\automl-agent\utils\embeddings.py:4
#       2 from langchain_community.vectorstores import FAISS
#       3 from langchain_text_splitters import RecursiveCharacterTextSplitter
# ----> 4 from langchain.retrievers import ContextualCompressionRetriever, BM25Retriever
#       5 from langchain.retrievers.document_compressors import CrossEncoderReranker
#       6 from langchain_community.cross_encoders import HuggingFaceCrossEncoder
#
# ModuleNotFoundError: No module named 'langchain.retrievers'
